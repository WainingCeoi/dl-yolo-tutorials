# %%
import torch

# %% [markdown]
# # Check PyTorch Installation

# %%
torch.rand(3, 4)
# Out:
# tensor([[0.5519, 0.1750, 0.1533, 0.3104],
#         [0.3972, 0.1795, 0.3436, 0.7506],
#         [0.6415, 0.8731, 0.4958, 0.3186]])

# %% [markdown]
# # Check MPS Availability

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
device
# Out:
# device(type='mps')
