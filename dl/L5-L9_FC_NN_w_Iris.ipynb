# %%
import sys
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Lecture 5: Create a Basic Neural Network

# %% [markdown]
# ```mermaid
# ---
# title: Nerual Network Diagram
# ---
# flowchart LR
#     A["**Input Layer**
#     4 Features of Iris"] --> B["**Hidden Layer 1**
#     Number of Neurons"]
#     B --> C["**Hidden Layer 2**
#     Number of Neurons"]
#     C --> D["**Output**
#     Classes of Iris"]
# ```

# %% [markdown]
# ## Section 1: Create a Model Class that Inherits nn.Module

# %%
class Model(nn.Module):
    def __init__(self, input_features=4, h1=8, h2=9, output_features=3):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(input_features, h1)
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, output_features)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

# %% [markdown]
# ## Section 2: Pick a manual seed for randomization and Create an instance of Model

# %%
torch.manual_seed(48)
device = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")
model = Model().to(device)
device
# Out:
# device(type='mps')

# %% [markdown]
# # Lecture 6: Load Data and Train Neural Network Model

# %% [markdown]
# ## Section 1: Data Preprocessing
# 1. Load Iris Data.
# 2. Set X, y. And convert data type.
#     * X default datatype is float64, but tensor only support float32. Must convert to float 32 or will cause error.
#     * y default datatype is int64, can convert to float32 or numpy int_, won't cause error if not make changes.
# 3. Split train and test datasets. Convert into Tensor.
#     * Method 1: Concisely, Recommended ✅
#     * Method 2: Originally, Not Recommended ❌
#         * Step 1: Train Test Split:
#           ```{python}
#           X_train, X_test, y_train, y_test = train_test_split(X, y)
#           ```
#         * Step 2: Convert Datasets into Tensor:
#           ```{python}
#           X_train = torch.tensor(X_train)
#           X_test = torch.tensor(X_test)
#           y_train = torch.tensor(y_train)
#           y_test = torch.tensor(y_test)
#           ```

# %%
iris = pd.read_csv(r"./Datasets/Iris.csv")
iris["variety"], uniques = pd.factorize(iris["variety"])

X = iris.drop(columns="variety").astype(np.float32).to_numpy()
y = iris["variety"].astype(np.int_).to_numpy()

X_train, X_test, y_train, y_test = [torch.tensor(data).to(device) for data in train_test_split(X, y, random_state=50)]

# %% [markdown]
# ## Section 2: Setting Model Parameters
# 1. Set the criterion of model to measure the error, how far off the predictions are from the data.
# 2. Choose Adam optimizer.
# 3. If error doesn't go down after a bunch of iteration (epochs), lower learning rate.
#
# ### Terminology:
# * lr: Learning Rate
# * Epochs: one run through all the training data in our network

# %%
criterion = nn.CrossEntropyLoss()
optimizor = torch.optim.Adam(model.parameters(), lr=0.1)

# %% [markdown]
# ## Section 3: Train Our Model
# 1. Use tqdm to show training progress.
# 2. Go forward and get a prediction.
# 3. Measure the train_loss / error, going to be high at first.
# 4. Keep track of our losses, and print them out.
# 5. Do some back propagation: take the error rate of forward propagation and feed it back through the network to find tune weights.

# %%
epochs = 200
losses = []
pbar = tqdm(range(epochs), desc="Training Progress", unit="epochs", file=sys.stdout)
for idx in pbar:
    y_prediction = model(X_train)
    train_loss = criterion(y_prediction, y_train)
    losses.append(train_loss.item())
    pbar.set_postfix({"loss": f"{train_loss:.4f}"})

    optimizor.zero_grad()
    train_loss.backward()
    optimizor.step()
# Out:
# Training Progress: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:09<00:00, 21.05epochs/s, loss=0.0334]

# %% [markdown]
# ## Section 4: Graph it out

# %%
plt.plot(range(epochs), losses)
plt.ylabel("Loss/Error")
plt.xlabel("Epochs")
plt.title("Learning Curve")
# Out:
# Text(0.5, 1.0, 'Learning Curve')

# %% [markdown]
# # Lecture 7: Evaluate Test Data Set on Network

# %% [markdown]
# ## Section 1: Overall Evaluation on Test Datasets

# %%
with torch.no_grad():
    y_eval = model(X_test)
    test_loss = criterion(y_eval, y_test)

test_loss
# Out:
# tensor(0.1227, device='mps:0')

# %% [markdown]
# ## Section 2: Detailed Evaluation on Test Datasets
# ### Quick note for .item() Method:
# * A method for extracting value from a single-element array or tensor as a standard Python scalar.
# * Useful when the argmax() operation results in a single index.
# * E.g., from a 1D array or when finding the maximum across a specific dimension that collapses the output to a single value.

# %%
correct = 0
with torch.no_grad():
    for idx, data in enumerate(X_test):
        y_eval = model(data)
        print(f"{idx+1}:\t{y_eval} \t {uniques[y_eval.argmax().item()]} \t {uniques[y_test[idx].item()]}")

        if y_eval.argmax() == y_test[idx]:
            correct += 1

print(f"We got {correct} / {len(X_test)}!")
# Out:
# 1:	tensor([ -2.6914,   8.7363, -10.3888], device='mps:0') 	 Versicolor 	 Versicolor
# 2:	tensor([-14.5978,   3.7331,   5.6757], device='mps:0') 	 Virginica 	 Versicolor
# 3:	tensor([ 29.2833,  16.1485, -63.7618], device='mps:0') 	 Setosa 	 Setosa
# 4:	tensor([ 33.7257,  17.1184, -72.7678], device='mps:0') 	 Setosa 	 Setosa
# 5:	tensor([-17.5750,   3.5189,   8.1877], device='mps:0') 	 Virginica 	 Virginica
# 6:	tensor([-21.4117,   3.1209,  11.6004], device='mps:0') 	 Virginica 	 Virginica
# 7:	tensor([-18.3462,   3.0786,   9.4038], device='mps:0') 	 Virginica 	 Virginica
# 8:	tensor([ 25.9830,  15.3384, -57.0317], device='mps:0') 	 Setosa 	 Setosa
# 9:	tensor([ 27.6795,  15.0623, -60.1861], device='mps:0') 	 Setosa 	 Setosa
# 10:	tensor([-14.6606,   3.6048,   5.9097], device='mps:0') 	 Virginica 	 Versicolor
# 11:	tensor([ 29.7587,  15.9084, -64.5740], device='mps:0') 	 Setosa 	 Setosa
# 12:	tensor([-20.1791,   3.4620,  10.1842], device='mps:0') 	 Virginica 	 Virginica
# 13:	tensor([ 27.3235,  15.1797, -59.5503], device='mps:0') 	 Setosa 	 Setosa
# 14:	tensor([-19.2511,   3.4063,   9.5870], device='mps:0') 	 Virginica 	 Virginica
# 15:	tensor([-7.6967,  6.1441, -2.9244], device='mps:0') 	 Versicolor 	 Versicolor
# 16:	tensor([ 26.3171,  15.0811, -57.5635], device='mps:0') 	 Setosa 	 Setosa
# 17:	tensor([ -2.3091,   9.0569, -11.1379], device='mps:0') 	 Versicolor 	 Versicolor
# 18:	tensor([ 32.1939,  16.6371, -69.5977], device='mps:0') 	 Setosa 	 Setosa
# 19:	tensor([ -1.6931,   8.7987, -11.2138], device='mps:0') 	 Versicolor 	 Versicolor
# 20:	tensor([-13.2676,   5.0313,   2.8029], device='mps:0') 	 Versicolor 	 Versicolor
# 21:	tensor([-22.0990,   3.0383,  12.2238], device='mps:0') 	 Virginica 	 Virginica
# 22:	tensor([-3.6935,  7.8329, -8.3337], device='mps:0') 	 Versicolor 	 Versicolor
# 23:	tensor([ 37.2818,  18.0960, -80.0657], device='mps:0') 	 Setosa 	 Setosa
# 24:	tensor([-18.4629,   4.0496,   8.0593], device='mps:0') 	 Virginica 	 Virginica
# 25:	tensor([-6.9164,  7.9409, -6.1216], device='mps:0') 	 Versicolor 	 Versicolor
# 26:	tensor([-25.8082,   3.0516,  14.8999], device='mps:0') 	 Virginica 	 Virginica
# 27:	tensor([-7.2185,  7.5574, -5.3365], device='mps:0') 	 Versicolor 	 Versicolor
# 28:	tensor([-9.5244,  6.4100, -1.9667], device='mps:0') 	 Versicolor 	 Versicolor
# 29:	tensor([-4.1039,  8.6489, -9.2228], device='mps:0') 	 Versicolor 	 Versicolor
# 30:	tensor([-21.0393,   3.2426,  11.1468], device='mps:0') 	 Virginica 	 Virginica
# 31:	tensor([-17.6236,   3.8138,   7.7868], device='mps:0') 	 Virginica 	 Virginica
# 32:	tensor([  2.9673,  11.0417, -17.9142], device='mps:0') 	 Versicolor 	 Versicolor
# 33:	tensor([-7.2868,  6.6495, -3.9642], device='mps:0') 	 Versicolor 	 Versicolor
# 34:	tensor([-21.7213,   3.1276,  11.8201], device='mps:0') 	 Virginica 	 Virginica
# 35:	tensor([ 30.4199,  16.1943, -65.9769], device='mps:0') 	 Setosa 	 Setosa
# 36:	tensor([ 26.5476,  14.7435, -57.8598], device='mps:0') 	 Setosa 	 Setosa
# 37:	tensor([-6.1201,  6.6927, -4.8815], device='mps:0') 	 Versicolor 	 Versicolor
# 38:	tensor([-15.6897,   3.4544,   6.8894], device='mps:0') 	 Virginica 	 Virginica
# We got 36 / 38!

# %% [markdown]
# # Lecture 8: New Data on the Network

# %%
new_iris1 = torch.tensor([4.7, 3.2, 1.3, 0.2]).to(device)
new_iris2 = torch.tensor([5.9, 3.0, 5.1, 1.8]).to(device)
new_iris3 = torch.tensor([4.8, 3.5, 1.2, 0.5]).to(device)

with torch.no_grad():
    iris1_tensor = model(new_iris1)
    iris2_tensor = model(new_iris2)

iris1_tensor, uniques[iris1_tensor.argmax().item()], iris2_tensor, uniques[iris2_tensor.argmax().item()]
# Out:
# (tensor([ 28.6968,  15.2309, -62.2249], device='mps:0'),
#  'Setosa',
#  tensor([-15.3836,   3.6321,   6.4082], device='mps:0'),
#  'Virginica')

# %% [markdown]
# # Lecture 9: Save, Load, Check Neural Network Model

# %%
torch.save(model.state_dict(), r"Model/IRIS.pt")

new_model = Model().to(device)
new_model.load_state_dict(torch.load(r"./Model/IRIS.pt", weights_only=True))

with torch.no_grad():
    iris3_tensor = new_model(new_iris3)
new_model.eval(), iris3_tensor, uniques[iris3_tensor.argmax().item()]
