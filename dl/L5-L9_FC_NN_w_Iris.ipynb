# %%
import sys
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Lecture 5: Create a Basic Neural Network

# %% [markdown]
# ```mermaid
# ---
# title: Nerual Network Diagram
# ---
# flowchart LR
#     A["**Input Layer**
#     4 Features of Iris"] --> B["**Hidden Layer 1**
#     Number of Neurons"]
#     B --> C["**Hidden Layer 2**
#     Number of Neurons"]
#     C --> D["**Output**
#     Classes of Iris"]˚
# ```

# %% [markdown]
# ## Create a Model Class that Inherits nn.Module

# %%
class Model(nn.Module):
    def __init__(self, input_features=4, h1=8, h2=9, output_features=3):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(input_features, h1)
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, output_features)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x


torch.manual_seed(42)

# Create an instance of Model and put to Mac GPU, calls "mps"
model = Model()

# %% [markdown]
# ## Pick a manual seed for randomization and Create an instance of Model

# %%
torch.manual_seed(48)
model = model

# %% [markdown]
# # Lecture 6: Load Data and Train Neural Network Model

# %% [markdown]
# ## Data Preprocessing
# 1. Load Iris Data.
# 2. Set X, y. And convert data type.
#     * X default datatype is float64, but tensor only support float32. Must convert to float 32 or will cause error.
#     * y default datatype is int64, can convert to float32 or numpy int_, won't cause error if not make changes.
# 3. Split train and test datasets. Convert into Tensor.
#     * Method 1: Concisely, Recommended ✅
#     * Method 2: Originally, Not Recommended ❌
#         * Step 1: Train Test Split:
#           ```{python}
#           X_train, X_test, y_train, y_test = train_test_split(X, y)
#           ```
#         * Step 2: Convert Datasets into Tensor:
#           ```{python}
#           X_train = torch.tensor(X_train)
#           X_test = torch.tensor(X_test)
#           y_train = torch.tensor(y_train)
#           y_test = torch.tensor(y_test)
#           ```

# %%
iris = pd.read_csv(r"./Datasets/Iris.csv")
iris["variety"], uniques = pd.factorize(iris["variety"])

X = iris.drop(columns="variety").astype(np.float32).to_numpy()
y = iris["variety"].astype(np.int_).to_numpy()

X_train, X_test, y_train, y_test = [torch.tensor(data) for data in train_test_split(X, y, random_state=50)]

# %% [markdown]
# ## Setting Model Parameters
# 1. Set the criterion of model to measure the error, how far off the predictions are from the data.
# 2. Choose Adam optimizer.
# 3. If error doesn't go down after a bunch of iteration (epochs), lower learning rate.
#
# ### Terminology:
# * lr: Learning Rate
# * Epochs: one run through all the training data in our network

# %%
criterion = nn.CrossEntropyLoss()
optimizor = torch.optim.Adam(model.parameters(), lr=0.1)

# %% [markdown]
# ## Train Our Model
# 1. Use tqdm to show training progress.
# 2. Go forward and get a prediction.
# 3. Measure the train_loss / error, going to be high at first.
# 4. Keep track of our losses, and print them out.
# 5. Do some back propagation: take the error rate of forward propagation and feed it back through the network to find tune weights.

# %%
epochs = 200
losses = []
pbar = tqdm(range(epochs), desc="Training Progress", unit="epochs", file=sys.stdout)
for idx in pbar:
    y_prediction = model.forward(X_train)
    train_loss = criterion(y_prediction, y_train)
    losses.append(train_loss.item())
    pbar.set_postfix({"loss": f"{train_loss:.4f}"})

    optimizor.zero_grad()
    train_loss.backward()
    optimizor.step()
# Out:
# Training Progress: 100%|██████████| 200/200 [00:00<00:00, 274.34epochs/s, loss=0.0444]

# %% [markdown]
# ## Graph it out

# %%
plt.plot(range(epochs), losses)
plt.ylabel("Loss/Error")
plt.xlabel("Epochs")
plt.title("Learning Curve")
# Out:
# Text(0.5, 1.0, 'Learning Curve')

# %% [markdown]
# # Lecture 7: Evaluate Test Data Set on Network

# %% [markdown]
# ## Evaluate Model on Test Data Set (Validate Model on Test Set)
# 1. Get Overall Loss.
# 2. Step Into Details.
#
# ### Quick note for .item() Method:
# * A method for extracting value from a single-element array or tensor as a standard Python scalar.
# * Useful when the argmax() operation results in a single index.
# * E.g., from a 1D array or when finding the maximum across a specific dimension that collapses the output to a single value.

# %%
with torch.no_grad():
    y_eval = model.forward(X_test)
    test_loss = criterion(y_eval, y_test)

test_loss
# Out:
# tensor(0.0943)

# %%
correct = 0
with torch.no_grad():
    for idx, data in enumerate(X_test):
        y_eval = model.forward(data)
        print(f"{idx+1}:\t{y_eval} \t {uniques[y_eval.argmax().item()]} \t {uniques[y_test[idx].item()]}")

        if y_eval.argmax() == y_test[idx]:
            correct += 1

print(f"We got {correct} / {len(X_test)}!")
# Out:
# 1:	tensor([-8.0375,  5.2659, -4.1861]) 	 Versicolor 	 Versicolor
# 2:	tensor([-19.6172,   4.6423,   5.7874]) 	 Virginica 	 Versicolor
# 3:	tensor([ 17.2638,   7.0926, -26.3417]) 	 Setosa 	 Setosa
# 4:	tensor([ 17.9829,   7.4047, -27.4517]) 	 Setosa 	 Setosa
# 5:	tensor([-24.7186,   4.5660,   9.7953]) 	 Virginica 	 Virginica
# 6:	tensor([-31.5594,   4.4291,  15.3997]) 	 Virginica 	 Virginica
# 7:	tensor([-26.9421,   3.8818,  12.9130]) 	 Virginica 	 Virginica
# 8:	tensor([ 15.1695,   6.6342, -23.9840]) 	 Setosa 	 Setosa
# 9:	tensor([ 16.2122,   6.6560, -24.6778]) 	 Setosa 	 Setosa
# 10:	tensor([-19.0005,   4.4514,   5.7272]) 	 Virginica 	 Versicolor
# 11:	tensor([ 17.0584,   7.0138, -26.0033]) 	 Setosa 	 Setosa
# 12:	tensor([-30.8200,   4.6018,  14.2917]) 	 Virginica 	 Virginica
# 13:	tensor([ 16.3275,   6.7035, -24.8610]) 	 Setosa 	 Setosa
# 14:	tensor([-28.0464,   4.4976,  12.4371]) 	 Virginica 	 Virginica
# 15:	tensor([-12.2157,   4.9909,  -0.4976]) 	 Versicolor 	 Versicolor
# 16:	tensor([ 16.1161,   6.6032, -24.5521]) 	 Setosa 	 Setosa
# 17:	tensor([-7.3999,  5.2542, -4.6325]) 	 Versicolor 	 Versicolor
# 18:	tensor([ 17.7715,   7.3153, -27.1206]) 	 Setosa 	 Setosa
# 19:	tensor([-5.5778,  5.1160, -5.7297]) 	 Versicolor 	 Versicolor
# 20:	tensor([-19.2907,   5.0474,   4.7318]) 	 Versicolor 	 Versicolor
# 21:	tensor([-33.5006,   4.6150,  16.7690]) 	 Virginica 	 Virginica
# 22:	tensor([-7.5999,  4.9753, -3.9219]) 	 Versicolor 	 Versicolor
# 23:	tensor([ 18.8787,   7.7834, -28.8551]) 	 Setosa 	 Setosa
# 24:	tensor([-26.9680,   5.5585,   9.4494]) 	 Virginica 	 Virginica
# 25:	tensor([-13.8386,   5.4556,  -0.1973]) 	 Versicolor 	 Versicolor
# 26:	tensor([-39.9591,   5.3392,  20.5508]) 	 Virginica 	 Virginica
# 27:	tensor([-13.8545,   5.3486,   0.0269]) 	 Versicolor 	 Versicolor
# 28:	tensor([-15.3369,   5.1166,   1.6196]) 	 Versicolor 	 Versicolor
# 29:	tensor([-9.9701,  5.3850, -2.9680]) 	 Versicolor 	 Versicolor
# 30:	tensor([-31.7807,   4.4732,  15.3880]) 	 Virginica 	 Virginica
# 31:	tensor([-26.0056,   5.0218,   9.8089]) 	 Virginica 	 Virginica
# 32:	tensor([-1.4374,  5.1525, -8.8942]) 	 Versicolor 	 Versicolor
# 33:	tensor([-12.1662,   5.2167,  -0.9976]) 	 Versicolor 	 Versicolor
# 34:	tensor([-32.1162,   4.4952,  15.6989]) 	 Virginica 	 Virginica
# 35:	tensor([ 17.2834,   7.1089, -26.3559]) 	 Setosa 	 Setosa
# 36:	tensor([ 15.9973,   6.5651, -24.3410]) 	 Setosa 	 Setosa
# 37:	tensor([-10.2238,   4.7606,  -1.5092]) 	 Versicolor 	 Versicolor
# 38:	tensor([-22.5349,   4.1890,   8.8936]) 	 Virginica 	 Virginica
# We got 36 / 38!

# %% [markdown]
# # Lecture 8: New Data on the Network

# %%
new_iris1 = torch.tensor([4.7, 3.2, 1.3, 0.2])
new_iris2 = torch.tensor([5.9, 3.0, 5.1, 1.8])
new_iris3 = torch.tensor([4.8, 3.5, 1.2, 0.5])

with torch.no_grad():
    iris1_tensor = model.forward(new_iris1)
    iris2_tensor = model.forward(new_iris2)

iris1_tensor, uniques[iris1_tensor.argmax().item()], iris2_tensor, uniques[iris2_tensor.argmax().item()]
# Out:
# (tensor([ 16.3043,   6.6949, -24.8221]),
#  'Setosa',
#  tensor([-21.5404,   4.5335,   7.4504]),
#  'Virginica')

# %% [markdown]
# # Lecture 9: Save and Load our Neural Network Model
# 1. Save our NN Model.
# 2. Load the Saved Model.
# 3. Make sure it Loaded Correctly.

# %%
torch.save(model.state_dict(), r"./Iris_Model.pt")

new_model = Model()
new_model.load_state_dict(torch.load("iris_model.pt", weights_only=True))

with torch.no_grad():
    iris3_tensor = new_model.forward(new_iris3)
new_model.eval(), iris3_tensor, uniques[iris3_tensor.argmax().item()]
# Out:
# (Model(
#    (fc1): Linear(in_features=4, out_features=8, bias=True)
#    (fc2): Linear(in_features=8, out_features=9, bias=True)
#    (out): Linear(in_features=9, out_features=3, bias=True)
#  ),
#  tensor([ 16.5327,   6.7915, -25.1798]),
#  'Setosa')
