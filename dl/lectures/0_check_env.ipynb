# %%
import torch

# %% [markdown]
# # Check PyTorch Installation

# %%
torch.rand(3, 4)
# Out:
# tensor([[0.5681, 0.1294, 0.7233, 0.2344],
#         [0.1359, 0.2978, 0.3036, 0.2811],
#         [0.1790, 0.0718, 0.7575, 0.2143]])

# %% [markdown]
# # Check MPS Availability

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
device
# Out:
# device(type='mps')
