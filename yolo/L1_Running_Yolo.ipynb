# %% [markdown]
# # Lecture 1: Running Yolo

# %%
from ultralytics import YOLO

# %%
model = YOLO("Yolo_Models/yolo11x.pt")
results = model("Images/1.jpg")
results[0].show()
# Out:
# image 1/1 /Users/xuweining/PycharmProjects/YoloTutorial/Images/1.jpg: 384x640 7 persons, 1 bus, 6 backpacks, 844.5ms
# Speed: 3.9ms preprocess, 844.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
