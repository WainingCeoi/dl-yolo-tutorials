# %% [markdown]
# # Lecture 1: Running Yolo

# %%
from ultralytics import YOLO

# %%
model = YOLO("Yolo_Model/yolo11x.pt")
results = model("Images/1.jpg")
results[0].show()
# Out:
# image 1/1 /Users/xuweining/PycharmProjects/Yolo Tutorial/Images/1.jpg: 384x640 7 persons, 1 bus, 6 backpacks, 801.3ms
# Speed: 3.7ms preprocess, 801.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
